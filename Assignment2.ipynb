# %% [markdown]
# # 1. Read the dataset to the python environment.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
cars=pd.read_csv('cars_data.csv')

# %% [markdown]
# # 2. Check for the null values present in the dataset.

# %%
cars.isnull()
# Out:
#        Make  Model  Nickname  Car Gender  Buyer Gender  Buyer Age  Buzzword  \
# 0     False  False     False       False         False      False     False
# 1     False  False     False       False         False      False     False
# 2     False  False     False       False         False      False     False
# 3     False  False     False       False         False      False     False
# 4     False  False     False       False         False      False     False
# ...     ...    ...       ...         ...           ...        ...       ...
# 9995  False  False     False       False         False      False     False
# 9996  False  False     False       False         False      False     False
# 9997  False  False     False       False         False      False     False
# 9998  False  False     False       False         False      False     False
# 9999  False  False     False       False         False      False     False
#
# ...

# %% [markdown]
# # 3.Plot a bar graph of male vs female buyers participated in the sales.

# %%
plt.figure()
plt.hist(cars['Buyer Gender'])
plt.title('Bar graph of male vs female buyers',fontsize=15)
plt.xlabel('Buyers',fontsize=10)
plt.ylabel('Count',fontsize=10)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# # 4.Find the top 5 cars based on their sales price.

# %%
carss=cars['Sale Price'].nlargest(5)
carss
# Out:
# 5984    99997.65
# 1270    99991.91
# 3460    99983.38
# 9032    99978.17
# 302     99973.44
# Name: Sale Price, dtype: float64

# %%
c1=cars.iloc[5984,0:2]
c2=cars.iloc[1270,0:2]
c3=cars.iloc[3460,0:2]
c4=cars.iloc[9032,0:2]
c5=cars.iloc[302,0:2]
print('The Top 5 cars based on their sales price are=',c1,c2,c3,c4,c5)
# Out:
# The Top 5 cars based on their sales price are= Make     Volkswagen
# Model     Jetta III
# Name: 5984, dtype: object Make     Audi
# Model      A6
# Name: 1270, dtype: object Make     Lexus
# Model       LX
# Name: 3460, dtype: object Make     Mazda
# Model     MX-6
# Name: 9032, dtype: object Make     Lexus
# Model       ES
# Name: 302, dtype: object

# %% [markdown]
# # 5.Find the least 5 cars based on their Resell price.

# %%
carsl=cars['Resell Price'].nsmallest(5)
carsl
# Out:
# 2446    2000.84
# 4933    2005.44
# 566     2014.09
# 2538    2017.24
# 5869    2017.83
# Name: Resell Price, dtype: float64

# %%
c6=cars.iloc[2446,0:2]
c7=cars.iloc[4933,0:2]
c8=cars.iloc[566,0:2]
c9=cars.iloc[2538,0:2]
c10=cars.iloc[5869,0:2]
print('The least 5 cars based on their Resell price',c6,c7,c8,c9,c10)
# Out:
# The least 5 cars based on their Resell price Make     Chevrolet
# Model         1500
# Name: 2446, dtype: object Make             GMC
# Model    Savana 1500
# Name: 4933, dtype: object Make     Jaguar
# Model        XF
# Name: 566, dtype: object Make     Mitsubishi
# Model        3000GT
# Name: 2538, dtype: object Make     Infiniti
# Model         G37
# Name: 5869, dtype: object
